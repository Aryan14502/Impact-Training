# %% [markdown]
# Types of binary tree based on the number of children:
# Following are the types of binary tree based on the number of children:
#
# Full binary tree
# Degenerate binary tree
# Skewed binary tree
#
# Types of binary tree on the basis of the completion of levels:
#
# Complete binary tree
# Perfect binary tree
# Balanced binary tree
#
# Some special types of trees:
# On the basis of node values, the binary tree can be classsified into the following special types:
#
# Binary Search tree
# AVL tree
# Segment tree

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None

class Tree:
    def __init__(self):
        self.root = None
    def insert(self,key):
        if self.root is None:
            self.root = Node(self.data)
            return root
        if root is None:
            root = Node(data)
            return root
        elif data>root.data:
            root.right = self.insert(root.right,data)
        elif data<self.root.data:
            root.left = self.insert(root.left,data)
        return root
    def inorder(self,root):
        if root is None:
            return 
        self.inorder(root.left)
        print(root.data)
        self.inorder(root.right)
    def search(self,root,target):
        if self.root.data == target:
            return root
        elif target>self.root.data:
            self.root.right = self.search(self.root.right,target)  
        elif target>self.root.data:
            self.left.right = self.search(self.root.left,target)

t1 = Tree()
t1.insert(5) 
t1.insert(53) 
t1.insert(15) 
t1.insert(57)
t1.insert(25) 
t1.insert(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 37
#      34             self.left.right = self.search(self.root.left,target)
#      36 t1 = Tree()
# ---> 37 t1.insert(5)
#      38 t1.insert(53)
#      39 t1.insert(15)
#
# Cell In[4], line 12, in Tree.insert(self, key)
#      10 def insert(self,key):
#      11     if self.root is None:
# ---> 12         self.root = Node(self.data)
#      13         return root
#      14     if root is None:
#
# AttributeError: 'Tree' object has no attribute 'data'

# %%
class node:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None
class Tree:
  def __init__(self):
    self.root=None
  def insert(self,root,data): #root.left
    if root is None:
      root=node(data) #node = 4
      return root
    elif data>root.data:  #root.data=23
      root.right=self.insert(root.right,data)
    elif data<root.data:
      root.left=self.insert(root.left,data)   #root=None
    return root
  #def traverse(self,root,data):
   # if root is None:
   #   root=node(data)
   #   return root
  def showTree(self,root):
    #if self.root is None:
    #  return root
    #print(root.data,end=" ")
    #return self.showTree(root.left)
    #return self.showTree(root.right)
    if root:
      '''pre-order'''
      #print(root.data,end=" ")
      #self.showTree(root.left)
      #self.showTree(root.right)
     
      # '''inorder format'''
      # self.showTree(root.left)
      # print(root.data,end=" ")
      # self.showTree(root.right)
     
      '''post-order'''
      self.showTree(root.left)
      self.showTree(root.right)
      print(root.data,end=" ")
     
     
  def search(self,root,key):
    if root is None:
      return -1
    if root.data==key:
      return root.data
    elif root.data>key:
      return self.search(root.left,key)
    else:
      return self.search(root.right,key)
    return -1
  def Inorder_Successor(self,node):
    current=node
    while(current.l is not None):
      current=current.l
    return current
   
  def remove_key(self,root,key):
    if root is None:
      return root
    elif key<root.data:
      root.left=self.remove_key(root.left,key)
    elif key>root.data:
      root.right=self.remove_key(root.right,key)

T1=Tree()
root=T1.insert(T1.root,34)
T1.insert(root,45)
T1.insert(root,23)
T1.insert(root,25)
T1.insert(root,36)
T1.insert(root,8)
T1.showTree(root)
print()
print(T1.search(root,46))
T1.remove_key(root,23)
print(T1.showTree(root))
