# %%
class node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None


class Tree:
    def __init__(self):
        self.root = None

    def insert(self,root,data):
        if root is None:
            root=node(data)
            return root
        if data>root.data:
            root.right=self.insert(root.right,data)
        if data<root.data:
            root.left=self.insert(root.left,data)
            
    def showTree(self,root):
        if self.root:
            print(root.data,end=" ")
            root.left = self.showTree(root.left)
            root.right = self.showTree(root.right)
    
    def search(self,root,target):

        if(root is None):
            return -1

        if (root.data==target):
            return root.data
        elif root.data>target:
            self.search(root.left,target)
        else:
            self.search(root.right,target)
        return -1
    
    def remove_key(root, key):
        if root is None:
            return root
        if key<root.key:
            root.l = remove_key(root.l, key)
            


r1 = Tree()
root = None 
root = r1.insert(root,25)
r1.insert(root,6)
r1.insert(root,43)
r1.insert(root,5)
r1.insert(root,50)
r1.insert(root,2)
r1.showTree(root)

# %%
#AVL Tree

#create a tree node

class TreeNode(object):
    def __init__(self,key):
        sekf.key = key 
        self.left = None
        self.right = None
        self.height = 1
        
class AVLTree(object):
    
    def insert_node(self,root,key):
        if not root:
            return TreeNode(key)
        elif key<root.key:
            root.left = self.insert_node(root.left,key)
        else:
            root.right = self.insert_node(root.right,key)
            
        root.height = 1 + max(self.getHeight(root.left), self.getHeight(root.right))
        
        balanceFactor = self.getBalance(root)
        if balanceFactor > 1:
            if key < root.left.key:
                return self.rightRotate(root)
            else:
                root.left = self.leftRotate(root.left)
                return self.rightRotate(root)
            
        if balanceFactor < -1:
            if key > root.right.key:
                return self.leftRotate(root)
            else:
                root.right = self.rightRotate(root.right)
                return self.leftRotate(root)
    
    
    def leftRotate(self,z):
        y = z.right
        T2 = y.left
        y.left = z
        z.right = T2
        z.height = 1 + max(self.getHeight(z.left), self.getHeight(z.right)) 
        y.height = 1 + max(self.getHeight(y.left), self.getHeight(y.right))
        return y   
    
    def rightRotate(self,z):
        y = z.left
        T3 = y.right
        y.right = z
        z.left = T3
        z.height = 1 + max(self.getHeight(z.left), self.getHeight(z.right)) 
        y.height = 1 + max(self.getHeight(y.left), self.getHeight(y.right))
        return y
    
    def getHeight(self,root):
        if not root:
            return 0
        return root.height
    
    def getBalance(self, root):
        if not root:
            return 0
        return self.getHeight(root.left) - self.getHeight(root.right)
    
    def delete_node(self,root,)

# %%
#stack implementation using array

class stack:
    def __init__(self,size):
        self.size = size
        self.stack = []
        self.top = -1
    def push(self,data):
        if self.isfull():
            print("Stack is overflow")
        else:
            self.stack.append(data)
            self.top+=1
    def pop(self):
        if self.isempty():
            print("Stack is underflow")
        else:
            self.stack.pop()
            self.top-=1
    def peek(self):
            return self.stack[self.top]
    def isfull(self):
        if self.top == self.size:
            return True
        else:
            return False
    def isempty(self):
        if self.top == -1:
            return True
        else:
            return False
        
S1 = stack(5)
S1.push(56)
S1.push(7)
S1.push(65)
S1.push(6)
S1.push(4)
S1.push(1)
S1.push("hello")
S1.peek()
# Out:
# Stack is overflow
# 1

# %%
#implementation of stack through linked list

class Node:
    def __init__(self,data=0):
        self.data = data 
        self.next = None

class Stack:
    def __init__(self,size):
        self.head = None
        self.size = size 
        self.top = -1
    def push(self,data):
        if self.top == self.size-1:
            print("stack overflow")
            return
        newnode = node(data)
        newnode.next = self.head
        self.head = newnode 
        self.top+=1
    def pop(self):
        if self.top==-1:
            print("stack underflow")
            return
        self.head = self.head.next
        self.top-=1
    def peek(self):
        return self.head.data
    def isfull(self):
        if self.top==self.size-1:
            return True
        return False
    def isempty(self):
        if self.top==-1:
            return True 
        return False

s = Stack(5) 
s.isempty()
# Out:
# True

# %%
#programs
#write a program to reverse/insert at bottom/delete middle element of stack


class stack:
    def __init__(self,size):
        self.size = size
        self.stack = []
        self.top = -1
    def push(self,data):
        if self.isfull():
            print("Stack is overflow")
        else:
            self.stack.append(data)
            self.top+=1
    def pop(self):
        if self.isempty():
            print("Stack is underflow")
        else:
            self.stack.pop()
            self.top-=1
    def peek(self):
            return self.stack[self.top]
    def isfull(self):
        if self.top == self.size:
            return True
        else:
            return False
    def isempty(self):
        if self.top == -1:
            return True
        else:
            return False

'''def insertBottom(data):
    if s.isempty() or s.isfull():
        print("stack underflow or overflow")
    while self.top != self.isempty():
        stk = [self.push((self.pop()))]
    self.push(key)
    while self.top != self.isfull():
        self.push(self.pop(stk))'''

def insert_at_bottom(stack,data):
    if stack.isempty():
        stack.push(data)
        return stack
    ele = stack.peek()
    stack.pop()
    insert_at_bottom(stack,data)
    stack.push(ele)
    return stack

key = eval(input())
s = stack(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 46
#      44 key = eval(input())
#      45 s = stack(5)
# ---> 46 s.insertBottom(key)
#
# AttributeError: 'stack' object has no attribute 'insertBottom'

# %%
# balanced parenthesis
'''ex = []()
ex = ][
ex = 2+4/(9*{3+5})
ex = {[}]'''

example = input()
stack = []
def balancedParenthesis(stack,example):
    for i in example:
        if '}' or ')' or ']':
            print("invalid parenthesis")
        else:
            if '{' or '(' or '[':
                stack.push()
