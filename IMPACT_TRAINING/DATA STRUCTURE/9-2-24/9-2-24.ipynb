# %%
#circular queue using array



class CircularQueue():
    
    def __init__(self,size):
        self.size = size
        self.Queue = [None]*size
        self.front = -1
        self.rear = -1
    
    def isEmpty(self):
        if self.front == -1 and self.rear == -1:
            return True 
        else:
            return False
    
    def isFull(self):
        if self.front == (self.rear+1)%self.size:
            return True
        else:
            return False  
            
    def insert(self,key):
        if isFull()==True:
            return False
        elif isEmpty()==True:
            self.Queue[self.rear]=key
            self.rear += 1
            self.front += 1
        else:
            self.Queue[self.rear]=key
            self.rear = ((self.rear+1)%self.size)
            
    def delete(self):
        if isEmpty()==True:
            return False
        else:
            self.Queue.pop()
            self.front = ((self.front+1)%self.size)
    
    def printQueue(self):
        if isEmpty()==True:
            print("Queue is empty")
        else:
            for i in range ((self.rear+1)%self.size):
                print(Queue[self.front])

# %%
#circular queue using linked list

class None:
    def __init__(self,value=0):
        self.data = value
        self.next = None 

class CircularQueue:
    def __init__(self,front,rear,size):
        self.head = None
        self.front = None
        self.rear = None
        self.size = size 
    
    def insert(self,key):
        newNode = Node()
        if self.head == None:
            self.head = newNode
            newNode.data = key
            self.front = newNode
            self.rear = newNode
